# %% [markdown]
# # Parton Shower Monte Carlos
#
# ## Learning Objectives
#
# By the end of this chapter, students should be able to:
#
# - explain why parton showers model multiple emissions in high-energy events.
# - describe the basic ideas of branching, ordering variables, and Sudakov suppression.
# - relate shower evolution to observable jet structure.
